# %%
import json
import os

def transform_data(original_data):
    transformed_data = []
    
    for table in original_data:
        # Estrai colonne
        columns = [{"text": header[0]} for header in table["column_header"]]
        
        # Estrai righe
        rows = []
        for row in table["data"]:
            cells = [{"text": cell} for cell in row]
            rows.append({"cells": cells})

        # Costruisci la nuova struttura
        transformed_table = {
            "columns": columns,
            "rows": rows,
            "tableId": table["id"],
            "documentTitle": table.get("title", ""),  # Usa il titolo reale se disponibile
            "documentUrl": table.get("url", "")  # Usa l'URL reale se disponibile
        }
        transformed_data.append(transformed_table)
    
    return transformed_data

def main(input_file, output_file):
    original_data = []
    
    # Leggi i dati dal file di input
    try:
        with open(input_file, 'r') as infile:
            for line in infile:
                original_data.append(json.loads(line.strip()))
    except Exception as e:
        print(f"Error reading input file: {e}")
        return

    # Trasforma i dati
    transformed_result = transform_data(original_data)
    
    # Scrivi i dati trasformati nel file di output come JSON Lines
    try:
        with open(output_file, 'w') as outfile:
            for item in transformed_result:
                outfile.write(json.dumps(item) + '\n')  # Scrivi ogni oggetto JSON su una nuova riga
    except Exception as e:
        print(f"Error writing output file: {e}")
        return
    
    print(f"Output written to {output_file}")

if __name__ == "__main__":
    input_file_path = "/home/sara.ferrari/data/AITQA/tables/AITQA_tables.jsonl"  # Percorso del tuo file di input
    output_file_path = "/home/sara.ferrari/data/AITQA/tables/tables.jsonl"  # Percorso desiderato per il file di output
    
    # Verifica che il file di input esista
    if os.path.exists(input_file_path):
        main(input_file_path, output_file_path)
    else:
        print(f"Input file {input_file_path} does not exist.")
# Out:
# Output written to /home/sara.ferrari/data/AITQA/tables/tables.jsonl

# %%
import json
import csv

# Funzione per processare una singola tabella
def process_table(table_data):
    title = table_data["title"]  # Nome del file CSV sarà basato su 'title'
    cells = table_data["cells"]

    # Organizza le celle in una matrice in base ai loro indici di riga e colonna
    max_row = max(cell["row_idx"] for cell in cells)
    max_col = max(cell["col_idx"] for cell in cells)

    # Inizializza una matrice vuota per la tabella
    table = [["" for _ in range(max_col + 1)] for _ in range(max_row + 1)]

    # Riempie la matrice con i valori dalle celle
    for cell in cells:
        row = cell["row_idx"]
        col = cell["col_idx"]
        # Rimuove il delimitatore "|" dai dati
        table[row][col] = cell["text"].replace("|", "").strip()

    # Scrivi la tabella su un file CSV con il titolo
    csv_file_name = f"/home/sara.ferrari/data/AITQA/tables_csv/{title}.csv"
    with open(csv_file_name, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerows(table)

    print(f"File CSV creato: {csv_file_name}")

# Funzione principale per leggere il file JSONL e processare ciascuna tabella
def convert_jsonl_to_csv(jsonl_file_path):
    with open(jsonl_file_path, mode="r", encoding="utf-8") as file:
        for line in file:
            table_data = json.loads(line.strip())
            process_table(table_data)

# Esegui la conversione
jsonl_file_path = "/home/sara.ferrari/data/AITQA/tables/transformed_tables4.jsonl"   # Sostituisci con il percorso del tuo file JSONL
convert_jsonl_to_csv(jsonl_file_path)
# Out:
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-0.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-1.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-2.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-3.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-4.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-5.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-6.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-7.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-8.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-9.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-10.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-11.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-12.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-13.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-14.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-15.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-16.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-17.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-18.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-19.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-20.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-21.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-22.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-23.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-24.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-25.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-26.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-27.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-28.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-29.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-30.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-31.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-32.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-33.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-34.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-35.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-36.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-37.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-38.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-39.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-40.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-41.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-42.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-43.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-44.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-45.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-46.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-47.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-48.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-49.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-50.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-51.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-52.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-53.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-54.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-55.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-56.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-57.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-58.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-59.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-60.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-61.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-62.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-63.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-64.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-65.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-66.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-67.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-68.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-69.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-70.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-71.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-72.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-73.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-74.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-75.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-76.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-77.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-78.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-79.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-80.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-81.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-82.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-83.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-84.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-85.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-86.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-87.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-88.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-89.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-90.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-91.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-92.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-93.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-94.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-95.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-96.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-97.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-98.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-99.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-100.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-101.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-102.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-103.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-104.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-105.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-106.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-107.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-108.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-109.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-110.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-111.csv
# File CSV creato: /home/sara.ferrari/data/AITQA/tables_csv/tab-112.csv
